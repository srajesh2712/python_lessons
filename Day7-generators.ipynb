# %%
[x * x for x in range(1, 10)]
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81 ]

# %%
sqgen = (x * x for x in range(1, 10))

# %%
next(sqgen)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-18-23c7a5dd3db7> in <module>
# ----> 1 next(sqgen)
#
# StopIteration:

# %%
# suppose i want a function to pause with state of variable and return back when called again, i will
# use yield keyword

def myfun():
    for x in range(1, 10):
        yield x * x
    yield ('generator calls limited')

# %%
gen = myfun()

# %%
list(gen)
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 'generator calls limited']

# %%
for x in gen:
    print(x)
# Out:
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81
# generator calls limited

# %%
next(gen)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-34-6e72e47198db> in <module>
# ----> 1 next(gen)
#
# StopIteration:
